# %%
## Green Space Data Exploration

## Janurary 30, 2022

## Estefany Garcia

# For this assignment I will be exploring a new dataset that my group plans on integrating into our final project to understand the access to green spaces.

# %%
# First I will import libraries necessary to explore the data.

# %%
# for spatial data
import geopandas as gpd

# for plotting
import matplotlib.pyplot as plt

# for network analysis
import networkx as nx

# for street network analysis
import osmnx as ox

# for basemaps
import contextily as ctx
# Out:
# /opt/conda/lib/python3.9/site-packages/geopandas/_compat.py:106: UserWarning: The Shapely GEOS version (3.9.1-CAPI-1.14.2) is incompatible with the GEOS version PyGEOS was compiled with (3.10.1-CAPI-1.16.0). Conversions between both will be slow.
#   warnings.warn(

# %%
# to give more power to your figures (plots)
import matplotlib.pyplot as plt

# %%
# First I will be uplaoding the data and calling it "greenspace"

# %%
greenspace=gpd.read_file('Department of Recreation and Parks GIS Map of Park Boundaries.geojson')

# %%
#First I want to see what variables exist within this dataset.

# %%
greenspace.info
# Out:
# <bound method DataFrame.info of                                address                               name  \
# 0                   3400 Wilshire blvd  Robert F Kennedy Inspiration Park
# 1                  4702 N. Figueroa St                SYCAMORE GROVE PARK
# 2                    351 N. Gaffey St.             San Pedro Welcome Park
# 3                     1015 S.Wilton PL                  WILTON PLACE PARK
# 4                1780 E.Santa Ana Blvd            WATTS CULTURAL CRESCENT
# ..                                 ...                                ...
# 505  4501 S. CENTRAL AVE, LA, CA 90011  VERNON BRANCH LIBRARY POCKET PARK
# 506    4948-4956 YORK BLVD,LA,CA 90042              YORK BLVD POCKET PARK
# 507                    1010 W. 25th St           HOOVER RECREATION CENTER
# 508                 5340 Canoga Avenue    OLD FIRE STATION 84 POCKET PARK
# 509               14353 W. Fox Streeet         FOX AND LAUREL CANYON PARK
#
# ...

# %%
# Now I want to explore the amount of data that exists.

# %%
greenspace.shape
# Out:
# (510, 4)

# %%
# Now we will see the variables available in this dataset
greenspace.columns.to_list()
# Out:
# ['address', 'name', 'objectid', 'geometry']

# %%
# Now I will make a basic plot showing the Parks throuhgout the City of Los Angeles
greenspace.plot()
# Out:
# <AxesSubplot:>

# %%
# I am still unsure how to add a layer map with the City of Los Angeles, but that is something I want to go to office hours to get support in.

# %%
# Now I will apply another code to be able to make a different map.


greenspace.plot(figsize=(12,12))
# Out:
# <AxesSubplot:>

# %%
# By adding the (figsize=(12,12)) you are able to get the image from before closer.

# %%
# So it seems as though this data is soley park locations. I think this information will be great to add to our housing data or other data.

greenspace.head()
# Out:
#                  address                               name objectid  \
# 0     3400 Wilshire blvd  Robert F Kennedy Inspiration Park        1
# 1    4702 N. Figueroa St                SYCAMORE GROVE PARK        2
# 2      351 N. Gaffey St.             San Pedro Welcome Park        3
# 3       1015 S.Wilton PL                  WILTON PLACE PARK        4
# 4  1780 E.Santa Ana Blvd            WATTS CULTURAL CRESCENT        5
#
#                                             geometry
# 0  MULTIPOLYGON (((-118.29796 34.06162, -118.2969...
# 1  MULTIPOLYGON (((-118.20110 34.10134, -118.2011...
# 2  MULTIPOLYGON (((-118.29286 33.74600, -118.2928...
# 3  MULTIPOLYGON (((-118.31504 34.05232, -118.3149...
# 4  MULTIPOLYGON (((-118.24221 33.93945, -118.2422...

# %%
# I tried to make my map a bit more detailed by following the code below. I see a legend came out but I would like feedback or examples on how a legend can support this data more intentionally. I wonder if the legend will make more sense when we add a housing layer to the data. 
greenspace.plot(figsize=(12,12),
                 column='name',
                 legend=True, 
                 scheme='NaturalBreaks')
# Out:
# <AxesSubplot:>

# %%
# Overall in this homework I feel more confident in adding the basic types of code, when I make mistakes I feel less nervous and double check if I misspelled something or if I missed a parenthasis, overall I feel less confued using this tool but would now like to get support in adding base maps and adding other datasets in one notebook.
